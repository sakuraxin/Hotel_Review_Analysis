# %%
import pandas as pd
import numpy as np

# %%
staff_pos_data = pd.read_pickle('staff_pos_data')
staff_neg_data = pd.read_pickle('staff_neg_data')
loc_pos_data = pd.read_pickle('loc_pos_data') ###loc == location
rm_pos_data = pd.read_pickle('rm_pos_data') ##rm == room 
rm_neg_data = pd.read_pickle('rm_neg_data')
bk_pos_data = pd.read_pickle('bk_pos_data') ##bk == breakfast
bk_neg_data = pd.read_pickle('bk_neg_data')
bed_pos_data = pd.read_pickle('bed_pos_data')
bed_neg_data = pd.read_pickle('bed_neg_data')
bath_neg_data = pd.read_pickle('bath_neg_data') ##bath == bathroom

# %% [markdown]
# List of hotel based on value of **Average_Score**

# %%
overall_data = pd.read_csv('hotel_score.csv')
overall_list = overall_data.sort_values('Average_Score', ascending = False)
overall_list = overall_list.drop(columns = ['index'])
overall_list.head()
# Out:
#                                Hotel_Name  Average_Score  count
# 1203                           Ritz Paris            9.8     28
# 481                 H10 Casa Mimosa 4 Sup            9.6    116
# 472   H tel de La Tamise Esprit de France            9.6     61
# 3                                      41            9.6    103
# 772                      Hotel The Serras            9.6    213

# %%
overall_list = overall_list.reset_index(drop = True)
overall_list.head()
# Out:
#                             Hotel_Name  Average_Score  count
# 0                           Ritz Paris            9.8     28
# 1                H10 Casa Mimosa 4 Sup            9.6    116
# 2  H tel de La Tamise Esprit de France            9.6     61
# 3                                   41            9.6    103
# 4                     Hotel The Serras            9.6    213

# %%
overall_list.to_csv('overall_list.csv')

# %% [markdown]
# # "staff" in positive reviews
# Return a list of hotel descendingly by score of Avg_score and (mean(pos)-mean(neg))/(mean(pos)

# %%
staff_pos_list = staff_pos_data.groupby('Hotel_name').agg({'pos': 'mean', 'neg': 'mean', 'Avg_score': 'mean'})
staff_pos_list.head()
# Out:
#                                           neg        pos  Avg_score
# Hotel_name
# 11 Cadogan Gardens                  20.365517  69.240230        8.7
# 1K Hotel                            27.890244  68.829268        7.7
# 25hours Hotel beim MuseumsQuartier  16.299588  78.984362        8.8
# 41                                  11.659375  67.742188        9.6
# 45 Park Lane Dorchester Collection  12.014286  54.600000        9.4

# %%
staff_pos_list['score'] = (staff_pos_list.pos - staff_pos_list.neg) / staff_pos_list.pos

# %%
staff_pos_list.head()
# Out:
#                                           neg        pos  Avg_score     score
# Hotel_name
# 11 Cadogan Gardens                  20.365517  69.240230        8.7  0.705872
# 1K Hotel                            27.890244  68.829268        7.7  0.594791
# 25hours Hotel beim MuseumsQuartier  16.299588  78.984362        8.8  0.793635
# 41                                  11.659375  67.742188        9.6  0.827886
# 45 Park Lane Dorchester Collection  12.014286  54.600000        9.4  0.779958

# %%
staff_pos = staff_pos_list.sort_values(['Avg_score', 'score'], ascending = [False, False])
staff_pos.head()
# Out:
#                                            neg         pos  Avg_score  \
# Hotel_name
# Ritz Paris                           15.041667   60.441667        9.8
# H10 Casa Mimosa 4 Sup                13.511475  107.865574        9.6
# 41                                   11.659375   67.742188        9.6
# Haymarket Hotel                      11.886000   86.226000        9.6
# H tel de La Tamise Esprit de France   7.146341   91.500000        9.6
#
#                                         score
# Hotel_name
# Ritz Paris                           0.751137
# H10 Casa Mimosa 4 Sup                0.874738
# 41                                   0.827886
# Haymarket Hotel                      0.862153
# H tel de La Tamise Esprit de France  0.921898

# %% [markdown]
# # "location" in positive reviews
# Return a list of hotel descendingly by score of Avg_score and (mean(pos)-mean(neg))/(mean(pos)

# %%
loc_pos_list = loc_pos_data.groupby('Hotel_name').agg({'pos': 'mean', 'neg': 'mean', 'Avg_score': 'mean'})
loc_pos_list['score'] = (loc_pos_list.pos - loc_pos_list.neg) / loc_pos_list.pos
loc_pos = loc_pos_list.sort_values(['Avg_score', 'score'], ascending = [False, False])
loc_pos.head()
# Out:
#                              neg         pos  Avg_score     score
# Hotel_name
# Ritz Paris              0.000000   18.900000        9.8  1.000000
# Hotel The Serras        8.864706   98.903529        9.6  0.910370
# Haymarket Hotel        18.487805   82.773171        9.6  0.776645
# Hotel Casa Camper       8.026891  102.186555        9.6  0.921449
# H10 Casa Mimosa 4 Sup  15.407692  106.253846        9.6  0.854992

# %% [markdown]
# # "room" in positive reviews
# Return a list of hotel descendingly by score of Avg_score and (mean(pos)-mean(neg))/(mean(pos)

# %%
rm_pos_list = rm_pos_data.groupby('Hotel_name').agg({'pos': 'mean', 'neg': 'mean', 'Avg_score': 'mean'})
rm_pos_list['score'] = (rm_pos_list.pos - rm_pos_list.neg) / rm_pos_list.pos
rm_pos = rm_pos_list.sort_values(['Avg_score', 'score'], ascending = [False, False])
rm_pos.head()
# Out:
#                              neg         pos  Avg_score     score
# Hotel_name
# Ritz Paris             25.300000   63.142857        9.8  0.599321
# Hotel Casa Camper       7.005376  107.126882        9.6  0.934607
# Hotel The Serras       10.264000  105.600000        9.6  0.902803
# H10 Casa Mimosa 4 Sup  15.741176   90.941176        9.6  0.826908
# Haymarket Hotel        20.061364   85.338636        9.6  0.764921

# %% [markdown]
# # "breakfast" in positive reviews
# Return a list of hotel descendingly by Avg_score and score of (mean(pos)-mean(neg))/(mean(pos)

# %%
bk_pos_list = bk_pos_data.groupby('Hotel_name').agg({'pos': 'mean', 'neg': 'mean', 'Avg_score': 'mean'})
bk_pos_list['score'] = (bk_pos_list.pos - bk_pos_list.neg) / bk_pos_list.pos
bk_pos = bk_pos_list.sort_values(['Avg_score', 'score'], ascending = [False, False])
bk_pos.head()
# Out:
#                                            neg         pos  Avg_score  \
# Hotel_name
# Ritz Paris                            0.000000   85.200000        9.8
# Hotel Casa Camper                     8.732653  107.509184        9.6
# H tel de La Tamise Esprit de France   4.544444  109.111111        9.6
# 41                                    4.112500   82.725000        9.6
# H10 Casa Mimosa 4 Sup                14.960000   86.400000        9.6
#
#                                         score
# Hotel_name
# Ritz Paris                           1.000000
# Hotel Casa Camper                    0.918773
# H tel de La Tamise Esprit de France  0.958350
# 41                                   0.950287
# H10 Casa Mimosa 4 Sup                0.826852

# %% [markdown]
# # "bed" in positive reviews
# Return a list of hotel descendingly by score of Avg_score and (mean(pos)-mean(neg))/(mean(pos)

# %%
bed_pos_list = bed_pos_data.groupby('Hotel_name').agg({'pos': 'mean', 'neg': 'mean', 'Avg_score': 'mean'})
bed_pos_list['score'] = (bed_pos_list.pos - bed_pos_list.neg) / bed_pos_list.pos
bed_pos = bed_pos_list.sort_values(['Avg_score', 'score'], ascending = [False, False])
bed_pos.head()
# Out:
#                                            neg         pos  Avg_score  \
# Hotel_name
# Ritz Paris                            6.900000   79.050000        9.8
# Hotel Casa Camper                     8.369565  114.452174        9.6
# Hotel The Serras                     13.673684   91.994737        9.6
# 41                                    6.320000  102.240000        9.6
# H tel de La Tamise Esprit de France  17.628571  145.600000        9.6
#
#                                         score
# Hotel_name
# Ritz Paris                           0.912713
# Hotel Casa Camper                    0.926873
# Hotel The Serras                     0.851364
# 41                                   0.938185
# H tel de La Tamise Esprit de France  0.878925

# %% [markdown]
# # "room" in negative reviews
# Return a list of hotel descendingly by score of Avg_score and (mean(pos)-mean(neg))/(mean(pos)

# %%
rm_neg_list = rm_neg_data.groupby('Hotel_name').agg({'pos': 'mean', 'neg': 'mean', 'Avg_score': 'mean'})
rm_neg_list['score'] = (rm_neg_list.pos - rm_neg_list.neg) / rm_neg_list.pos
rm_neg = rm_neg_list.sort_values(['Avg_score', 'score'], ascending = [False, False])
rm_neg.head()
# Out:
#                                            neg        pos  Avg_score     score
# Hotel_name
# Ritz Paris                           43.250000  61.300000        9.8  0.294454
# Hotel Casa Camper                    30.080952  75.869048        9.6  0.603515
# Hotel The Serras                     21.146875  67.000000        9.6  0.684375
# 41                                   51.044444  36.355556        9.6 -0.404034
# H tel de La Tamise Esprit de France  16.200000  86.260000        9.6  0.812196

# %% [markdown]
# # "breakfast" in negative reviews
# Return a list of hotel descendingly by score of Avg_score and (mean(pos)-mean(neg))/(mean(pos)

# %%
bk_neg_list = bk_neg_data.groupby('Hotel_name').agg({'pos': 'mean', 'neg': 'mean', 'Avg_score': 'mean'})
bk_neg_list['score'] = (bk_neg_list.pos - bk_neg_list.neg) / bk_neg_list.pos
bk_neg = bk_neg_list.sort_values(['Avg_score', 'score'], ascending = [False, False])
bk_neg.head()
# Out:
#                                            neg        pos  Avg_score     score
# Hotel_name
# Ritz Paris                           13.800000  81.700000        9.8  0.831089
# H tel de La Tamise Esprit de France  13.566667  74.366667        9.6  0.817571
# Hotel The Serras                     31.828571  86.200000        9.6  0.630759
# Hotel Casa Camper                    35.725000  95.850000        9.6  0.627282
# Haymarket Hotel                      34.437500  67.075000        9.6  0.486582

# %% [markdown]
# # "staff" in negative reviews
# Return a list of hotel descendingly by score of Avg_score and (mean(pos)-mean(neg))/(mean(pos)

# %%
staff_neg_list = staff_neg_data.groupby('Hotel_name').agg({'pos': 'mean', 'neg': 'mean', 'Avg_score': 'mean'})
staff_neg_list['score'] = (staff_neg_list.pos - staff_neg_list.neg) / staff_neg_list.pos
staff_neg = staff_neg_list.sort_values(['Avg_score', 'score'], ascending = [False, False])
staff_neg.head()
# Out:
#                            neg        pos  Avg_score     score
# Hotel_name
# Ritz Paris             88.4000  68.200000        9.8 -0.296188
# Hotel Casa Camper       0.0000  41.333333        9.6  1.000000
# Hotel The Serras       21.0250  40.300000        9.6  0.478288
# H10 Casa Mimosa 4 Sup  45.9625  69.900000        9.6  0.342454
# Haymarket Hotel        31.0250  34.825000        9.6  0.109117

# %% [markdown]
# # "bed" in negative reviews
# Return a list of hotel descendingly by score of Avg_score and (mean(pos)-mean(neg))/(mean(pos)

# %%
bed_neg_list = bed_neg_data.groupby('Hotel_name').agg({'pos': 'mean', 'neg': 'mean', 'Avg_score': 'mean'})
bed_neg_list['score'] = (bed_neg_list.pos -bed_neg_list.neg) / bed_neg_list.pos
bed_neg = bed_neg_list.sort_values(['Avg_score', 'score'], ascending = [False, False])
bed_neg.head()
# Out:
#                                        neg    pos  Avg_score     score
# Hotel_name
# H tel de La Tamise Esprit de France  13.60  32.40        9.6  0.580247
# Haymarket Hotel                      25.98  42.32        9.6  0.386106
# H10 Casa Mimosa 4 Sup                46.00  63.50        9.6  0.275591
# 41                                   56.30  39.00        9.6 -0.443590
# Hotel The Serras                     14.00   0.00        9.6      -inf

# %% [markdown]
# # "bathroom" in negative reviews
# Return a list of hotel descendingly by score of Avg_score and (mean(pos)-mean(neg))/(mean(pos)

# %%
bath_neg_list = bath_neg_data.groupby('Hotel_name').agg({'pos': 'mean', 'neg': 'mean', 'Avg_score': 'mean'})
bath_neg_list['score'] = (bath_neg_list.pos -bath_neg_list.neg) / bath_neg_list.pos
bath_neg = bath_neg_list.sort_values(['Avg_score', 'score'], ascending = [False, False])
bath_neg.head()
# Out:
#                                   neg         pos  Avg_score     score
# Hotel_name
# H10 Casa Mimosa 4 Sup       35.900000  262.100000        9.6  0.863029
# Hotel Casa Camper           14.566667   93.033333        9.6  0.843425
# Hotel The Serras            16.675000   53.700000        9.6  0.689479
# Haymarket Hotel             58.600000   51.650000        9.6 -0.134560
# Milestone Hotel Kensington  14.000000  186.200000        9.5  0.924812

# %%
data = pd.read_pickle('Filling_nans')
data.head()
# Out:
#                                        Hotel_Address  \
# 0   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 1   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 2   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 3   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 4   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
#
#    Additional_Number_of_Scoring Review_Date  Average_Score   Hotel_Name  \
# 0                           194    8/3/2017            7.7  Hotel Arena
# 1                           194    8/3/2017            7.7  Hotel Arena
# 2                           194   7/31/2017            7.7  Hotel Arena
# 3                           194   7/31/2017            7.7  Hotel Arena
# 4                           194   7/24/2017            7.7  Hotel Arena
#
#   Reviewer_Nationality                                    Negative_Review  \
# 0              Russia    I am so angry that i made this post available...
# 1             Ireland                                         No Negative
# 2           Australia    Rooms are nice but for elderly a bit difficul...
# 3      United Kingdom    My room was dirty and I was afraid to walk ba...
# 4         New Zealand    You When I booked with your company on line y...
#
#    Review_Total_Negative_Word_Counts  Total_Number_of_Reviews  \
# 0                                397                     1403
# 1                                  0                     1403
# 2                                 42                     1403
# 3                                210                     1403
# 4                                140                     1403
#
#                                      Positive_Review  \
# 0   Only the park outside of the hotel was beauti...
# 1   No real complaints the hotel was great great ...
# 2   Location was good and staff were ok It is cut...
# 3   Great location in nice surroundings the bar a...
# 4    Amazing location and building Romantic setting
#
#    Review_Total_Positive_Word_Counts  \
# 0                                 11
# 1                                105
# 2                                 21
# 3                                 26
# 4                                  8
#
#    Total_Number_of_Reviews_Reviewer_Has_Given  Reviewer_Score  \
# 0                                           7             2.9
# 1                                           7             7.5
# 2                                           9             7.1
# 3                                           1             3.8
# 4                                           3             6.7
#
#                                                 Tags days_since_review  \
# 0  [' Leisure trip ', ' Couple ', ' Duplex Double...            0 days
# 1  [' Leisure trip ', ' Couple ', ' Duplex Double...            0 days
# 2  [' Leisure trip ', ' Family with young childre...            3 days
# 3  [' Leisure trip ', ' Solo traveler ', ' Duplex...            3 days
# 4  [' Leisure trip ', ' Couple ', ' Suite ', ' St...           10 days
#
#          lat       lng
# 0  52.360576  4.915968
# 1  52.360576  4.915968
# 2  52.360576  4.915968
# 3  52.360576  4.915968
# 4  52.360576  4.915968

# %% [markdown]
# Write each list to .csv file

# %%
staff_pos= staff_pos_list.reset_index()
staff_pos.head()
# Out:
#                            Hotel_name        neg        pos  Avg_score  \
# 0                  11 Cadogan Gardens  20.365517  69.240230        8.7
# 1                            1K Hotel  27.890244  68.829268        7.7
# 2  25hours Hotel beim MuseumsQuartier  16.299588  78.984362        8.8
# 3                                  41  11.659375  67.742188        9.6
# 4  45 Park Lane Dorchester Collection  12.014286  54.600000        9.4
#
#       score
# 0  0.705872
# 1  0.594791
# 2  0.793635
# 3  0.827886
# 4  0.779958

# %%
staff_pos.to_csv('staff_pos_list.csv')

# %%
loc_pos = loc_pos_list.reset_index()
loc_pos.to_csv('loc_pos_list.csv')
rm_pos = rm_pos_list.reset_index()
rm_pos.to_csv('rm_pos_list.csv')
bk_pos = bk_pos_list.reset_index()
bk_pos.to_csv('bk_pos_list.csv')
bed_pos = bed_pos_list.reset_index()
bed_pos.to_csv('bed_pos_list.csv')
rm_neg = rm_neg_list.reset_index()
rm_neg.to_csv('rm_neg_list.csv')
bk_neg = bk_neg_list.reset_index()
bk_neg.to_csv('bk_neg_list.csv')
staff_neg = staff_neg_list.reset_index()
staff_pos.to_csv('staff_neg_list.csv')
bed_neg = bed_neg_list.reset_index()
bed_neg.to_csv('bed_neg_list.csv')
bath_neg = bath_neg_list.reset_index()
bath_neg.to_csv('bath_neg_list.csv')
