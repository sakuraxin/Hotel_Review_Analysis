# %%
import pandas as pd
import numpy as np

# %%
staff_pos_data = pd.read_pickle('./data/staff_pos_data')
staff_neg_data = pd.read_pickle('./data/staff_neg_data')
loc_pos_data = pd.read_pickle('./data/loc_pos_data') ###loc == location
rm_pos_data = pd.read_pickle('./data/rm_pos_data') ##rm == room 
rm_neg_data = pd.read_pickle('./data/rm_neg_data')
bk_pos_data = pd.read_pickle('./data/bk_pos_data') ##bk == breakfast
bk_neg_data = pd.read_pickle('./data/bk_neg_data')
bed_pos_data = pd.read_pickle('./data/bed_pos_data')
bed_neg_data = pd.read_pickle('./data/bed_neg_data')
bath_neg_data = pd.read_pickle('./data/bath_neg_data') ##bath == bathroom

# %% [markdown]
# List of hotel based on value of **Average_Score**

# %%
overall_data = pd.read_csv('./data/hotel_score.csv')
overall_list = overall_data.sort_values('Average_Score', ascending = False)
overall_list = overall_list.drop(columns = ['index'])
overall_list.head()
# Out:
#                                Hotel_Name  Average_Score  count
# 1203                           Ritz Paris            9.8     28
# 481                 H10 Casa Mimosa 4 Sup            9.6    116
# 472   H tel de La Tamise Esprit de France            9.6     61
# 3                                      41            9.6    103
# 772                      Hotel The Serras            9.6    213

# %%
overall_list = overall_list.reset_index(drop = True)
overall_list.head()
# Out:
#                             Hotel_Name  Average_Score  count
# 0                           Ritz Paris            9.8     28
# 1                H10 Casa Mimosa 4 Sup            9.6    116
# 2  H tel de La Tamise Esprit de France            9.6     61
# 3                                   41            9.6    103
# 4                     Hotel The Serras            9.6    213

# %%
overall_list.to_csv('./data/overall_list.csv')

# %% [markdown]
# # "staff" in positive reviews
# Return a list of hotel descendingly by score of Avg_score and (mean(pos)-mean(neg))/(mean(pos)

# %%
staff_pos_list = staff_pos_data.groupby('Hotel_name').agg({'pos': 'mean', 'neg': 'mean', 'Avg_score': 'mean'})
staff_pos_list.head()
# Out:
#                                           neg        pos  Avg_score
# Hotel_name
# 11 Cadogan Gardens                  20.480460  69.542529        8.7
# 1K Hotel                            28.270732  69.202439        7.7
# 25hours Hotel beim MuseumsQuartier  16.440741  79.506584        8.8
# 41                                  12.143750  68.360937        9.6
# 45 Park Lane Dorchester Collection  12.942857  54.371429        9.4

# %%
staff_pos_list['score'] = (staff_pos_list.pos - staff_pos_list.neg) / staff_pos_list.pos

# %%
staff_pos_list.head()
# Out:
#                                           neg        pos  Avg_score     score
# Hotel_name
# 11 Cadogan Gardens                  20.480460  69.542529        8.7  0.705497
# 1K Hotel                            28.270732  69.202439        7.7  0.591478
# 25hours Hotel beim MuseumsQuartier  16.440741  79.506584        8.8  0.793215
# 41                                  12.143750  68.360937        9.6  0.822358
# 45 Park Lane Dorchester Collection  12.942857  54.371429        9.4  0.761955

# %%
staff_pos = staff_pos_list.sort_values(['Avg_score', 'score'], ascending = [False, False])
staff_pos.head()
# Out:
#                                            neg         pos  Avg_score  \
# Hotel_name
# Ritz Paris                           15.258333   60.350000        9.8
# H10 Casa Mimosa 4 Sup                14.011475  107.845902        9.6
# 41                                   12.143750   68.360937        9.6
# Haymarket Hotel                      12.166000   86.960000        9.6
# H tel de La Tamise Esprit de France   7.219512   92.031707        9.6
#
#                                         score
# Hotel_name
# Ritz Paris                           0.747169
# H10 Casa Mimosa 4 Sup                0.870079
# 41                                   0.822358
# Haymarket Hotel                      0.860097
# H tel de La Tamise Esprit de France  0.921554

# %% [markdown]
# # "location" in positive reviews
# Return a list of hotel descendingly by score of Avg_score and (mean(pos)-mean(neg))/(mean(pos)

# %%
loc_pos_list = loc_pos_data.groupby('Hotel_name').agg({'pos': 'mean', 'neg': 'mean', 'Avg_score': 'mean'})
loc_pos_list['score'] = (loc_pos_list.pos - loc_pos_list.neg) / loc_pos_list.pos
loc_pos = loc_pos_list.sort_values(['Avg_score', 'score'], ascending = [False, False])
loc_pos.head()
# Out:
#                              neg         pos  Avg_score     score
# Hotel_name
# Ritz Paris              0.000000   19.300000        9.8  1.000000
# Hotel The Serras        8.880000   99.587059        9.6  0.910832
# Haymarket Hotel        18.702439   84.063415        9.6  0.777520
# Hotel Casa Camper       8.189076  103.165546        9.6  0.920622
# H10 Casa Mimosa 4 Sup  15.441026  106.758974        9.6  0.855366

# %% [markdown]
# # "room" in positive reviews
# Return a list of hotel descendingly by score of Avg_score and (mean(pos)-mean(neg))/(mean(pos)

# %%
rm_pos_list = rm_pos_data.groupby('Hotel_name').agg({'pos': 'mean', 'neg': 'mean', 'Avg_score': 'mean'})
rm_pos_list['score'] = (rm_pos_list.pos - rm_pos_list.neg) / rm_pos_list.pos
rm_pos = rm_pos_list.sort_values(['Avg_score', 'score'], ascending = [False, False])
rm_pos.head()
# Out:
#                              neg         pos  Avg_score     score
# Hotel_name
# Ritz Paris             25.728571   62.642857        9.8  0.589282
# Hotel Casa Camper       7.100000  108.310753        9.6  0.934448
# Hotel The Serras       10.242000  106.066000        9.6  0.903437
# H10 Casa Mimosa 4 Sup  16.115686   90.560784        9.6  0.822046
# Haymarket Hotel        20.129545   85.881818        9.6  0.765613

# %% [markdown]
# # "breakfast" in positive reviews
# Return a list of hotel descendingly by Avg_score and score of (mean(pos)-mean(neg))/(mean(pos)

# %%
bk_pos_list = bk_pos_data.groupby('Hotel_name').agg({'pos': 'mean', 'neg': 'mean', 'Avg_score': 'mean'})
bk_pos_list['score'] = (bk_pos_list.pos - bk_pos_list.neg) / bk_pos_list.pos
bk_pos = bk_pos_list.sort_values(['Avg_score', 'score'], ascending = [False, False])
bk_pos.head()
# Out:
#                                            neg         pos  Avg_score  \
# Hotel_name
# Ritz Paris                            0.000000   85.450000        9.8
# Hotel Casa Camper                     8.940816  108.671429        9.6
# H tel de La Tamise Esprit de France   4.477778  109.677778        9.6
# 41                                    4.087500   82.825000        9.6
# H10 Casa Mimosa 4 Sup                15.350000   85.340000        9.6
#
#                                         score
# Hotel_name
# Ritz Paris                           1.000000
# Hotel Casa Camper                    0.917726
# H tel de La Tamise Esprit de France  0.959173
# 41                                   0.950649
# H10 Casa Mimosa 4 Sup                0.820131

# %% [markdown]
# # "bed" in positive reviews
# Return a list of hotel descendingly by score of Avg_score and (mean(pos)-mean(neg))/(mean(pos)

# %%
bed_pos_list = bed_pos_data.groupby('Hotel_name').agg({'pos': 'mean', 'neg': 'mean', 'Avg_score': 'mean'})
bed_pos_list['score'] = (bed_pos_list.pos - bed_pos_list.neg) / bed_pos_list.pos
bed_pos = bed_pos_list.sort_values(['Avg_score', 'score'], ascending = [False, False])
bed_pos.head()
# Out:
#                                            neg         pos  Avg_score  \
# Hotel_name
# Ritz Paris                            6.900000   79.500000        9.8
# Hotel Casa Camper                     8.469565  115.510870        9.6
# Hotel The Serras                     13.889474   92.497368        9.6
# 41                                    6.300000  102.740000        9.6
# H tel de La Tamise Esprit de France  17.685714  146.571429        9.6
#
#                                         score
# Hotel_name
# Ritz Paris                           0.913208
# Hotel Casa Camper                    0.926677
# Hotel The Serras                     0.849839
# 41                                   0.938680
# H tel de La Tamise Esprit de France  0.879337

# %% [markdown]
# # "room" in negative reviews
# Return a list of hotel descendingly by score of Avg_score and (mean(pos)-mean(neg))/(mean(pos)

# %%
rm_neg_list = rm_neg_data.groupby('Hotel_name').agg({'pos': 'mean', 'neg': 'mean', 'Avg_score': 'mean'})
rm_neg_list['score'] = (rm_neg_list.pos - rm_neg_list.neg) / rm_neg_list.pos
rm_neg = rm_neg_list.sort_values(['Avg_score', 'score'], ascending = [False, False])
rm_neg.head()
# Out:
#                                            neg        pos  Avg_score     score
# Hotel_name
# Ritz Paris                           46.550000  61.650000        9.8  0.244931
# Hotel Casa Camper                    30.426190  76.559524        9.6  0.602581
# Hotel The Serras                     21.450000  67.581250        9.6  0.682604
# 41                                   52.755556  36.722222        9.6 -0.436611
# H tel de La Tamise Esprit de France  16.380000  87.066667        9.6  0.811868

# %% [markdown]
# # "breakfast" in negative reviews
# Return a list of hotel descendingly by score of Avg_score and (mean(pos)-mean(neg))/(mean(pos)

# %%
bk_neg_list = bk_neg_data.groupby('Hotel_name').agg({'pos': 'mean', 'neg': 'mean', 'Avg_score': 'mean'})
bk_neg_list['score'] = (bk_neg_list.pos - bk_neg_list.neg) / bk_neg_list.pos
bk_neg = bk_neg_list.sort_values(['Avg_score', 'score'], ascending = [False, False])
bk_neg.head()
# Out:
#                                            neg        pos  Avg_score     score
# Hotel_name
# Ritz Paris                           13.800000  82.300000        9.8  0.832321
# H tel de La Tamise Esprit de France  13.566667  74.566667        9.6  0.818060
# Hotel The Serras                     32.128571  86.228571        9.6  0.627402
# Hotel Casa Camper                    36.150000  94.975000        9.6  0.619374
# Haymarket Hotel                      34.937500  67.800000        9.6  0.484698

# %% [markdown]
# # "staff" in negative reviews
# Return a list of hotel descendingly by score of Avg_score and (mean(pos)-mean(neg))/(mean(pos)

# %%
staff_neg_list = staff_neg_data.groupby('Hotel_name').agg({'pos': 'mean', 'neg': 'mean', 'Avg_score': 'mean'})
staff_neg_list['score'] = (staff_neg_list.pos - staff_neg_list.neg) / staff_neg_list.pos
staff_neg = staff_neg_list.sort_values(['Avg_score', 'score'], ascending = [False, False])
staff_neg.head()
# Out:
#                           neg        pos  Avg_score     score
# Hotel_name
# Ritz Paris             87.100  68.400000        9.8 -0.273392
# Hotel Casa Camper       0.000  42.266667        9.6  1.000000
# Hotel The Serras       21.800  40.500000        9.6  0.461728
# H10 Casa Mimosa 4 Sup  46.025  70.000000        9.6  0.342500
# Haymarket Hotel        30.950  35.100000        9.6  0.118234

# %% [markdown]
# # "bed" in negative reviews
# Return a list of hotel descendingly by score of Avg_score and (mean(pos)-mean(neg))/(mean(pos)

# %%
bed_neg_list = bed_neg_data.groupby('Hotel_name').agg({'pos': 'mean', 'neg': 'mean', 'Avg_score': 'mean'})
bed_neg_list['score'] = (bed_neg_list.pos -bed_neg_list.neg) / bed_neg_list.pos
bed_neg = bed_neg_list.sort_values(['Avg_score', 'score'], ascending = [False, False])
bed_neg.head()
# Out:
#                                        neg    pos  Avg_score     score
# Hotel_name
# H tel de La Tamise Esprit de France  13.55  32.75        9.6  0.586260
# Haymarket Hotel                      25.38  42.54        9.6  0.403385
# H10 Casa Mimosa 4 Sup                46.20  63.90        9.6  0.276995
# 41                                   58.45  39.10        9.6 -0.494885
# Hotel The Serras                     13.90   0.00        9.6      -inf

# %% [markdown]
# # "bathroom" in negative reviews
# Return a list of hotel descendingly by score of Avg_score and (mean(pos)-mean(neg))/(mean(pos)

# %%
bath_neg_list = bath_neg_data.groupby('Hotel_name').agg({'pos': 'mean', 'neg': 'mean', 'Avg_score': 'mean'})
bath_neg_list['score'] = (bath_neg_list.pos -bath_neg_list.neg) / bath_neg_list.pos
bath_neg = bath_neg_list.sort_values(['Avg_score', 'score'], ascending = [False, False])
bath_neg.head()
# Out:
#                               neg     pos  Avg_score     score
# Hotel_name
# H10 Casa Mimosa 4 Sup       36.80  252.40        9.6  0.854200
# Hotel Casa Camper           14.30   93.20        9.6  0.846567
# Hotel The Serras            16.70   53.55        9.6  0.688142
# Haymarket Hotel             60.75   53.25        9.6 -0.140845
# Milestone Hotel Kensington  13.90  185.60        9.5  0.925108

# %%
data = pd.read_pickle('Filling_nans')
data.head()
# Out:
#                                        Hotel_Address  \
# 0   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 1   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 2   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 3   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 4   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
#
#    Additional_Number_of_Scoring Review_Date  Average_Score   Hotel_Name  \
# 0                           194    8/3/2017            7.7  Hotel Arena
# 1                           194    8/3/2017            7.7  Hotel Arena
# 2                           194   7/31/2017            7.7  Hotel Arena
# 3                           194   7/31/2017            7.7  Hotel Arena
# 4                           194   7/24/2017            7.7  Hotel Arena
#
#   Reviewer_Nationality                                    Negative_Review  \
# 0              Russia    I am so angry that i made this post available...
# 1             Ireland                                         No Negative
# 2           Australia    Rooms are nice but for elderly a bit difficul...
# 3      United Kingdom    My room was dirty and I was afraid to walk ba...
# 4         New Zealand    You When I booked with your company on line y...
#
#    Review_Total_Negative_Word_Counts  Total_Number_of_Reviews  \
# 0                                397                     1403
# 1                                  0                     1403
# 2                                 42                     1403
# 3                                210                     1403
# 4                                140                     1403
#
#                                      Positive_Review  \
# 0   Only the park outside of the hotel was beauti...
# 1   No real complaints the hotel was great great ...
# 2   Location was good and staff were ok It is cut...
# 3   Great location in nice surroundings the bar a...
# 4    Amazing location and building Romantic setting
#
#    Review_Total_Positive_Word_Counts  \
# 0                                 11
# 1                                105
# 2                                 21
# 3                                 26
# 4                                  8
#
#    Total_Number_of_Reviews_Reviewer_Has_Given  Reviewer_Score  \
# 0                                           7             2.9
# 1                                           7             7.5
# 2                                           9             7.1
# 3                                           1             3.8
# 4                                           3             6.7
#
#                                                 Tags days_since_review  \
# 0  [' Leisure trip ', ' Couple ', ' Duplex Double...            0 days
# 1  [' Leisure trip ', ' Couple ', ' Duplex Double...            0 days
# 2  [' Leisure trip ', ' Family with young childre...            3 days
# 3  [' Leisure trip ', ' Solo traveler ', ' Duplex...            3 days
# 4  [' Leisure trip ', ' Couple ', ' Suite ', ' St...           10 days
#
#          lat       lng
# 0  52.360576  4.915968
# 1  52.360576  4.915968
# 2  52.360576  4.915968
# 3  52.360576  4.915968
# 4  52.360576  4.915968

# %% [markdown]
# Write each list to .csv file

# %%
staff_pos= staff_pos_list.reset_index()
staff_pos.head()
# Out:
#                            Hotel_name        neg        pos  Avg_score  \
# 0                  11 Cadogan Gardens  20.480460  69.542529        8.7
# 1                            1K Hotel  28.270732  69.202439        7.7
# 2  25hours Hotel beim MuseumsQuartier  16.440741  79.506584        8.8
# 3                                  41  12.143750  68.360937        9.6
# 4  45 Park Lane Dorchester Collection  12.942857  54.371429        9.4
#
#       score
# 0  0.705497
# 1  0.591478
# 2  0.793215
# 3  0.822358
# 4  0.761955

# %%
staff_pos.to_csv('staff_pos_list.csv')

# %%
loc_pos = loc_pos_list.reset_index()
loc_pos.to_csv('./data/loc_pos_list.csv')
rm_pos = rm_pos_list.reset_index()
rm_pos.to_csv('./data/rm_pos_list.csv')
bk_pos = bk_pos_list.reset_index()
bk_pos.to_csv('./data/bk_pos_list.csv')
bed_pos = bed_pos_list.reset_index()
bed_pos.to_csv('./data/bed_pos_list.csv')
rm_neg = rm_neg_list.reset_index()
rm_neg.to_csv('./data/rm_neg_list.csv')
bk_neg = bk_neg_list.reset_index()
bk_neg.to_csv('./data/bk_neg_list.csv')
staff_neg = staff_neg_list.reset_index()
staff_pos.to_csv('./data/staff_neg_list.csv')
bed_neg = bed_neg_list.reset_index()
bed_neg.to_csv('./data/bed_neg_list.csv')
bath_neg = bath_neg_list.reset_index()
bath_neg.to_csv('./data/bath_neg_list.csv')
